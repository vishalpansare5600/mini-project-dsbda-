# %%
import numpy as np
import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt

from wordcloud import WordCloud

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("Tweets.csv")
df
# Out:
#            textID                                               text  \
# 0      cb774db0d1                I`d have responded, if I were going
# 1      549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2      088c60f138                          my boss is bullying me...
# 3      9642c003ef                     what interview! leave me alone
# 4      358bd9e861   Sons of ****, why couldn`t they put them on t...
# ...           ...                                                ...
# 27476  4eac33d1c0   wish we could come see u on Denver  husband l...
# 27477  4f4c4fc327   I`ve wondered about rake to.  The client has ...
# 27478  f67aae2310   Yay good for both of you. Enjoy the break - y...
# 27479  ed167662a5                         But it was worth it  ****.
# 27480  6f7127d9d7     All this flirting going on - The ATG smiles...
#
#                                            selected_text sentiment
# 0                    I`d have responded, if I were going   neutral
# 1                                               Sooo SAD  negative
# 2                                            bullying me  negative
# 3                                         leave me alone  negative
# 4                                          Sons of ****,  negative
# ...                                                  ...       ...
# 27476                                             d lost  negative
# 27477                                      , don`t force  negative
# 27478                          Yay good for both of you.  positive
# 27479                         But it was worth it  ****.  positive
# 27480  All this flirting going on - The ATG smiles. Y...   neutral
#
# [27481 rows x 4 columns]

# %%
df.head() #dataframes
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative

# %%
df.columns
# Out:
# Index(['textID', 'text', 'selected_text', 'sentiment'], dtype='object')

# %%
print('length of data is', len(df))
# Out:
# length of data is 27481

# %%
df.shape
# Out:
# (27481, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27481 entries, 0 to 27480
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   textID         27481 non-null  object
#  1   text           27480 non-null  object
#  2   selected_text  27480 non-null  object
#  3   sentiment      27481 non-null  object
# dtypes: object(4)
# memory usage: 858.9+ KB

# %%
df.dtypes #series
# Out:
# textID           object
# text             object
# selected_text    object
# sentiment        object
# dtype: object

# %%
print('TOTAL COUNT OF COLUMN IN DATASET IS:', len(df.columns))
print('TOTAL LENGTH OF DATASET IS:', len(df))
# Out:
# TOTAL COUNT OF COLUMN IN DATASET IS: 4
# TOTAL LENGTH OF DATASET IS: 27481

# %%
df['textID'].nunique()
# Out:
# 27481

# %%
df['textID'].unique() #numpy
# Out:
# array(['cb774db0d1', '549e992a42', '088c60f138', ..., 'f67aae2310',
#        'ed167662a5', '6f7127d9d7'], dtype=object)

# %%
df = df[['textID','text','selected_text','sentiment']]
df.head()  #dataframe
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative

# %%
sns.countplot(x=df["sentiment"])
# Out:
# <AxesSubplot:xlabel='sentiment', ylabel='count'>

# %%
df['text'].mode() #series
# Out:
# 0                          \tREALLY?? oh.. sorry yall  lol
# 1                                _beckett Thanks so much !
# 2              You`ll be missed!!  Bring me back  a key...
# 3                       get lit  I am  http://bit.ly/OASQR
# 4             Good morning to you !  Its so pretty outs...
#                                ...
# 27475    zoombezi bay was soooo fun!! buuuut my legs ar...
# 27476    {cont} that right their is why fake btches sho...
# 27477    ~ Happy Star Wars Day.every one ~  ...may the ...
# 27478    ï¿½anisalovesu me too. I am so so upset,especi...
# 27479    ï¿½ï¿½h. iï¿½m gonna go in the 'big' house now...
# Name: text, Length: 27480, dtype: object

# %%
df['text'].fillna("Good morning to you !  Its so pretty outs...",inplace=True)

# %%
df['text'].head(10)
# Out:
# 0                  I`d have responded, if I were going
# 1        Sooo SAD I will miss you here in San Diego!!!
# 2                            my boss is bullying me...
# 3                       what interview! leave me alone
# 4     Sons of ****, why couldn`t they put them on t...
# 5    http://www.dothebouncy.com/smf - some shameles...
# 6    2am feedings for the baby are fun when he is a...
# 7                                           Soooo high
# 8                                          Both of you
# 9     Journey!? Wow... u just became cooler.  hehe....
# Name: text, dtype: object

# %%
positive=df[df['sentiment']=='positive']
wc=WordCloud(max_font_size=50, max_words=100, background_color="white").generate(str(positive['text']))
type(plt.figure(figsize=(10,10)))
plt.imshow(wc)
plt.axis("off")
plt.show()

# %%
negative=df[df['sentiment']=='negative']
wc=WordCloud(max_font_size=50, max_words=100, background_color="white").generate(str(negative['text']))
plt.figure(figsize=(10,10))
plt.imshow(wc)
plt.axis("off")
plt.show()

# %%
neutral=df[df['sentiment']=='neutral']
wc=WordCloud(max_font_size=50,max_words=100,background_color='white').generate(str(neutral['text']))
plt.figure(figsize=(10,10))
plt.imshow(wc)
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['sentiment'].value_counts().sum()
# Out:
# 27481

# %%
df.describe() #dataframe
# Out:
#             textID                                  text selected_text  \
# count        27481                                 27481         27480
# unique       27481                                 27481         22463
# top     cb774db0d1   I`d have responded, if I were going          good
# freq             1                                     1           199
#
#        sentiment
# count      27481
# unique         3
# top      neutral
# freq       11118

# %%
df[1:2]
# Out:
#        textID                                            text selected_text  \
# 1  549e992a42   Sooo SAD I will miss you here in San Diego!!!      Sooo SAD
#
#   sentiment
# 1  negative

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in d:\anaconda new\lib\site-packages (1.8.2.2)
# Requirement already satisfied: matplotlib in d:\anaconda new\lib\site-packages (from wordcloud) (3.5.2)
# Requirement already satisfied: pillow in d:\anaconda new\lib\site-packages (from wordcloud) (9.2.0)
# Requirement already satisfied: numpy>=1.6.1 in d:\anaconda new\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda new\lib\site-packages (from matplotlib->wordcloud) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\anaconda new\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda new\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda new\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda new\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda new\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\anaconda new\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df.isnull().sum() #dataframe
# Out:
# textID           0
# text             0
# selected_text    1
# sentiment        0
# dtype: int64

# %%
df['selected_text'].mode()
# Out:
# 0    good
# Name: selected_text, dtype: object

# %%
df['selected_text'].fillna("good",inplace=True) #dataframe

# %%
df.isnull().sum() #dataframe
# Out:
# textID           0
# text             0
# selected_text    0
# sentiment        0
# dtype: int64

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()
words = set(nltk.corpus.words.words())

# %%
sentence = df['text'][0]
sid.polarity_scores(sentence)['compound']
# Out:
# 0.0

# %%
data =input('Enter Tweet:')
p=sid.polarity_scores(data)['compound']
if(p>0):
    print('positive')
elif(p == 0):
    print('neutral')
else:
    print('negative')
# Out:
# Enter Tweet:is
# neutral
